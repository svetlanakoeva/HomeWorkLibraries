# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotiib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y =[3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]
plt.plot(y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
t = np.linspace(0, 10, 51)
f = np.cos(t)
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.plot(t, f, color = 'g')
plt.title('График f(t)', fontsize=18)
plt.xlabel('значения t')
plt.ylabel('значения f')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotiib inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# UsageError: Line magic function `%matplotiib` not found.

# %%
x = np.linspace(-3, 3, 51)
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.plot(x, y1)
ax1.set_title('график Y1')
ax1.set_xlim([-5, 5])
ax2.plot(x, y2)
ax2.set_title('график Y2')
ax3.plot(x, y3)
ax3.set_title('график Y3')
ax4.plot(x, y4)
ax4.set_title('график Y4')
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5288\3734713699.py in <module>
# ----> 1 fig, ax = plt.subplots(nrows=2, ncol=2)
#       2 ax1, ax2, ax3, ax4 = ax.flatten()
#       3 ax1.plot(x, y1)
#       4 ax1.set_title('график Y1')
#       5 ax1.set_xlim([-5, 5])
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1453
#    1454     """
# -> 1455     fig = figure(**fig_kw)
#    1456     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1457                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     806                 RuntimeWarning)
#     807
# --> 808         manager = new_figure_manager(
#     809             num, figsize=figsize, dpi=dpi,
#     810             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in new_figure_manager(*args, **kwargs)
#     325     """Create a new figure manager instance."""
#     326     _warn_if_gui_out_of_main_thread()
# --> 327     return _get_backend_mod().new_figure_manager(*args, **kwargs)
#     328
#     329
#
# C:\anaconda\lib\site-packages\matplotlib_inline\backend_inline.py in new_figure_manager(num, FigureClass, *args, **kwargs)
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#      28
#      29
#
# C:\anaconda\lib\site-packages\matplotlib\figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2290             %(Figure:kwdoc)s
#    2291         """
# -> 2292         super().__init__(**kwargs)
#    2293
#    2294         if layout is not None:
#
# C:\anaconda\lib\site-packages\matplotlib\figure.py in __init__(self, **kwargs)
#     214         self.stale = True
#     215         self.suppressComposite = None
# --> 216         self.set(**kwargs)
#     217
#     218     def _get_draw_artists(self, renderer):
#
# C:\anaconda\lib\site-packages\matplotlib\artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# C:\anaconda\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# C:\anaconda\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Figure' object has no property 'ncol'
